# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('medical_examination.csv')

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df['overweight'] = (df['weight'] / (df['height'] / 100) ** 2).apply(lambda x: 1 if x > 25 else 0)

# %%
df['cholesterol'] = df['cholesterol'].apply(lambda x: 1 if x > 1 else 0)
df['gluc'] = df['gluc'].apply(lambda x: 1 if x > 1 else 0)

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            0     0      0
# 1   1  20228       1     156    85.0    140     90            1     0      0
# 2   2  18857       1     165    64.0    130     70            1     0      0
# 3   3  17623       2     169    82.0    150    100            0     0      0
# 4   4  17474       1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio  overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %% [markdown]
# ## Categorical Plot

# %%
df_cat = pd.melt(df, id_vars=['cardio'], value_vars=['active', 'alco', 'cholesterol', 'gluc', 'overweight', 'smoke'])

# %%
df_cat.head()
# Out:
#    cardio variable  value
# 0       0   active      1
# 1       1   active      1
# 2       1   active      0
# 3       1   active      1
# 4       0   active      0

# %%
df_cat['total'] = 1

# %%
df_cat = df_cat.groupby(['cardio', 'variable', 'value'], as_index=False).count()

# %%
df_cat
# Out:
#     cardio     variable  value  total
# 0        0       active      0   6378
# 1        0       active      1  28643
# 2        0         alco      0  33080
# 3        0         alco      1   1941
# 4        0  cholesterol      0  29330
# 5        0  cholesterol      1   5691
# 6        0         gluc      0  30894
# 7        0         gluc      1   4127
# 8        0   overweight      0  15915
# 9        0   overweight      1  19106
# 10       0        smoke      0  31781
# 11       0        smoke      1   3240
# 12       1       active      0   7361
# 13       1       active      1  27618
# 14       1         alco      0  33156
# 15       1         alco      1   1823
# 16       1  cholesterol      0  23055
# 17       1  cholesterol      1  11924
# 18       1         gluc      0  28585
# 19       1         gluc      1   6394
# 20       1   overweight      0  10539
# 21       1   overweight      1  24440
# 22       1        smoke      0  32050
# 23       1        smoke      1   2929

# %%
fig = sns.catplot(data=df_cat, x='variable', y='total', hue='value', col='cardio', kind='bar')

# %% [markdown]
# ## Heat Map

# %%
df_heat = df[(df['ap_hi'] >= df['ap_lo']) &
            (df['height'] >= df['height'].quantile(0.025)) &
            (df['height'] <= df['height'].quantile(0.975)) &
            (df['weight'] >= df['weight'].quantile(0.025)) &
            (df['weight'] <= df['weight'].quantile(0.975))]

# %%
df_heat.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            0     0      0
# 1   1  20228       1     156    85.0    140     90            1     0      0
# 2   2  18857       1     165    64.0    130     70            1     0      0
# 3   3  17623       2     169    82.0    150    100            0     0      0
# 4   4  17474       1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio  overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %%
corr = df_heat.corr(method='pearson')

# %%
corr
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.002507  0.003426  0.000326  0.000149  0.003492
# age          0.002507  1.000000 -0.018132 -0.076932  0.070168  0.018689
# gender       0.003426 -0.018132  1.000000  0.505785  0.129979  0.005063
# height       0.000326 -0.076932  0.505785  1.000000  0.251503  0.004586
# weight       0.000149  0.070168  0.129979  0.251503  1.000000  0.027030
# ap_hi        0.003492  0.018689  0.005063  0.004586  0.027030  1.000000
# ap_lo        0.000484  0.153508  0.059947  0.017922  0.227922  0.072803
# cholesterol  0.003719  0.129996 -0.037605 -0.063522  0.135981  0.022807
# gluc         0.002289  0.086990 -0.021357 -0.030469  0.107072  0.011111
# smoke       -0.002732 -0.044371  0.337436  0.187830  0.056533 -0.001928
# alco        -0.000708 -0.026970  0.168637  0.089785  0.059917  0.000769
# active       0.005891 -0.011445  0.007864 -0.005661 -0.014430 -0.000222
# ...

# %%
mask = np.triu(corr)

# %%
pd.DataFrame(mask)
# Out:
#      0         1         2         3         4         5         6         7   \
# 0   1.0  0.002507  0.003426  0.000326  0.000149  0.003492  0.000484  0.003719
# 1   0.0  1.000000 -0.018132 -0.076932  0.070168  0.018689  0.153508  0.129996
# 2   0.0  0.000000  1.000000  0.505785  0.129979  0.005063  0.059947 -0.037605
# 3   0.0  0.000000  0.000000  1.000000  0.251503  0.004586  0.017922 -0.063522
# 4   0.0  0.000000  0.000000  0.000000  1.000000  0.027030  0.227922  0.135981
# 5   0.0  0.000000  0.000000  0.000000  0.000000  1.000000  0.072803  0.022807
# 6   0.0  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.150362
# 7   0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 8   0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corr, mask=mask, lw=1, annot=True, fmt='0.1f', square=False, center=0.08, cbar_kws={'shrink': 0.5})
# Out:
# <AxesSubplot:>
